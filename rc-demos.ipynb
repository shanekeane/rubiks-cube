# %%
from rubiks.cubes import Cube

# %%
cube1 = Cube()
cube1.plot()

# %%
cube1.U().F().D().R_prime().U_prime().L_prime().B_prime().F_prime().B().L().R().D_prime().plot()

# %%
cube2 = Cube(solved=False)
cube2.plot()

# %%
cube3 = Cube()
cube3.randomize().plot()
